# %% [markdown]
# # Assignment 1 - Computer Vision and Deep Learning
#
# ### Tevyn Vergara | 46421201 | Electrical & Biomedical Engineer

# %% [markdown]
# DISCLAIMER: Google Gemini 3 was used for this assignment for:
# 1. Layout tips (all questions)
# 2. Syntax checking (all questions)
# 3. Trouble shooting and debugging
# 4. Functionality tips and suggestions (all questions)
# 5. Tips and explanation for key functions/theories and purposes
#
# References:
# 1. Google. (2026, March 17). Methods of providing alterative text for accessibility on websites. [Generative AI chat]. Gemini 3. https://gemini.google.com/

# %% [markdown]
# ### Assignment Libraries - Please run this before running any question/section in this report

# %% [markdown]
# # Question 1 - Video Collage

# %% [markdown]
# 1. Coding of the solution to generate and display collage image. Please add one/two liner comments in the code (similar to your tutorial codes). (3 marks)
# 2. Describe how the collage image is generated in the report. Comment on the many challenges (lighting, day night vision, rain, clouds or other factors present in the video/image frames) and suggest possible solutions. Please do not add code snippet/screenshot in the report part. Here, we want to see your understanding of logic. For this part, we will conduct face to face interview. We will share details after the submission deadline. (2 marks)

# %% [markdown]
# PROGRESS:
#
# 1. Continue refining
# 2. Do commennts section (run through with Lecture 1-3 content)
# 3. Do Junyper Write up

# %% [markdown]
# # Question 2 - Road Sign Detection

# %% [markdown]
# 1. Coding of a solution to locate one sign, description and explanation of method, related images and graphs. Please add one/two liner comments in the code (similar to your tutorial codes). (2 marks)
# 2. Testing method on all other signs, modification of method as required, showing related images with detection overlay. (1 marks)
# 3. Comment on the many challenges to road sign detection including lighting, different shaped signs, different coloured signs, perspective distortion, angle of rotation, and so on and suggest possible solutions. Please do not add code snippet/screenshot in the report part. Here, we want to see your understanding of logic. For this part, we will conduct face to face interview. We will share details after the submission deadline. (2 marks)

# %% [markdown]
# PROGRESS:
#
# 1. Make draft

# %% [markdown]
# # Question 3 - Cartoonize

# %% [markdown]
# 1. Coding of K-means clustering based implementation. Please add one/two liner comments in the code (similar to your tutorial codes) (1 mark)
# 2. Coding of Bilateral filtering-based implementation. Please add one/two liner comments in the code (similar to your tutorial codes) (2 marks)
# 3. Improved (your own/inspired) method and implementation. Please add one/two liner comments in the code (similar to your tutorial codes) (3 marks)
# 4. A detailed report mentioning K-means clustering, Bilateral filtering-based, and your own improvements with output differences. Comment on the many challenges and suggest possible solutions. Please do not add code snippet/screenshot in the report part. Here, we want to see your understanding of logic. For this part, we will conduct face to face interview. We will share details after the submission deadline. (4 marks)

# %% [markdown]
# PROGRESS:
#
# 1. Make draft
