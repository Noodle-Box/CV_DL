# %% [markdown]
# # Question 1
#
# ### Tevyn Vergara | 46421201 | Electrical & Biomedical Engineer

# %% [markdown]
# DISCLAIMER: Google Gemini 3 was used for this assignment for:
# 1. Layout tips (all questions)
# 2. Syntax checking (all questions)
# 3. Trouble shooting and debugging
# 4. Functionality tips and suggestions (all questions)
# 5. Tips and explanation for key functions/theories and purposes
# 6. Re-organizing to look more modular and readable
#
# References:
# 1. Google. (2026, May 16). Methods of providing alterative text for accessibility on websites. [Generative AI chat]. Gemini 3. https://gemini.google.com/

# %% [markdown]
# ## Standard Imports for Assignment 3 ##
#
# Please run this before executing any other cell

# %%
import numpy as np
import matplotlib.pyplot as plt
import skimage
import medmnist

print(medmnist.__version__)
# Out:
# Please install the required packages first. Use `pip install -r requirements.txt`.
# 3.0.2

# %% [markdown]
# ResNet18
#
# Reference: https://medmnist.com/v2
#
# Accuracy: 0.998 (Look up formula)
#
# Area Under Curve: 0.958

# %% [markdown]
# ### QUESTIONS TO ASK TUTOR ON PRIVATE ###
#
# 1. H
